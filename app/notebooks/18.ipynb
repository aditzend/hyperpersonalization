# %% [markdown]
# Queremos ingestar todos los resumenes de cuenta usando pymupdf. Para ello, vamos a crear una función que nos permita extraer el texto de un pdf. Para ello, vamos a usar la librería pymupdf.

# %%
from pathlib import Path
from llama_index import download_loader

PyMuPDFReader = download_loader("PyMuPDFReader")

loader = PyMuPDFReader()
documents = loader.load_data(file_path=Path('../../data/mastercard/s3.pdf'), metadata=True)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 5.9 MB/s eta 0:00:001
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.1/30.1 MB 4.0 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
from llama_index import GPTVectorStoreIndex
index = GPTVectorStoreIndex.from_documents(documents)
index.query('cuanto gaste')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/alexander/Projects/hyperpersonalization/app/notebooks/18.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/Users/alexander/Projects/hyperpersonalization/app/notebooks/18.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> from llama_index import GPTVectorStoreIndex
# ----> <a href='vscode-notebook-cell:/Users/alexander/Projects/hyperpersonalization/app/notebooks/18.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> index = GPTVectorStoreIndex.from_documents(documents)
#       <a href='vscode-notebook-cell:/Users/alexander/Projects/hyperpersonalization/app/notebooks/18.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> index.query('cuanto gaste')
#
# File ~/Projects/hyperpersonalization/venv/lib/python3.9/site-packages/llama_index/indices/base.py:102, in BaseIndex.from_documents(cls, documents, storage_context, service_context, show_progress, **kwargs)
# ...

# %%
doc.chunks()
# Out:
# []

# %%
doc.json()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/alexander/Projects/hyperpersonalization/app/notebooks/17.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/alexander/Projects/hyperpersonalization/app/notebooks/17.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> doc.json()
#
# TypeError: 'list' object is not callable

# %%
chunks = doc.chunks()
chunks
# Out:
# []

# %%
from IPython.display import display, HTML
selected_section = None
# find a section in the document by title
for section in doc.sections():
    if section.title == '2.2.2 Technical features':
        selected_section = section
        break
# use include_children=True and recurse=True to fully expand the section. 
# include_children only returns at one sublevel of children whereas recurse goes through all the descendants
HTML(section.to_html(include_children=True, recurse=True))
# Out:
# <h1>Resumen N° 027051366624</h1>

# %%
HTML(doc.tables()[0].to_html())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/alexander/Projects/hyperpersonalization/app/notebooks/17.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/alexander/Projects/hyperpersonalization/app/notebooks/17.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> HTML(doc.tables()[0].to_html())
#
# IndexError: list index out of range

# %%
doc.json()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/alexander/Projects/hyperpersonalization/app/notebooks/17.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/Users/alexander/Projects/hyperpersonalization/app/notebooks/17.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> doc.json()
#
# TypeError: 'list' object is not callable

# %%
import os
s = os.environ.get("OPENAI_API_KEY")

# %%
from llama_index.readers.schema.base import Document
from llama_index import VectorStoreIndex

index = VectorStoreIndex([])
page = 0
for chunk in doc.chunks():
    
    index.insert(Document(text=chunk.to_context_text(), extra_info={}))
query_engine = index.as_query_engine()

# %%
response = query_engine.query("cuanto ruido hacen estas maquinas?")
print(response)
# Out:
# Estas máquinas hacen menos de 70 dB(A) de nivel de presión acústica constante en un lugar de trabajo, tanto si son enfriadas por agua como si son enfriadas por aire.

# %% [markdown]
# Estas máquinas hacen menos de 70 dB(A) de nivel de presión acústica constante en un lugar de trabajo, tanto si son enfriadas por agua como si son enfriadas por aire.

# %%
response = query_engine.query("cual es la maxima temperatura a la que puedo tener la maquina?")
print(response)
# Out:
# La máxima temperatura a la que se puede tener la máquina no se menciona en la información proporcionada.

# %%
response = query_engine.query("quiero un resumen de la tabla de caracteristicas tecnicas de la compacta Vario 16")
print(response)
# Out:
# La tabla de características técnicas de la Compacta Vario 16 no se menciona en la información proporcionada.

# %%
doc.json[190]['page_idx']
# Out:
# 14

# %%
doc.json[190]
# Out:
# {'block_class': 'cls_16',
#  'block_idx': 295,
#  'left': 105.51,
#  'level': 5,
#  'name': '2.2.3 Machine lay-out',
#  'page_idx': 14,
#  'table_rows': [{'block_idx': 295,
#    'cells': [{'cell_value': 'Model', 'col_span': 1},
#     {'cell_value': 'Dimensions cm', 'col_span': 2},
#     {'cell_value': 'Weight', 'col_span': 2}],
#    'type': 'table_header'},
#   {'block_idx': 296,
#    'cells': [{'cell_value': ''},
#     {'cell_value': 'Width'},
#     {'cell_value': 'Depth'},
#     {'cell_value': 'Height'},
#     {'cell_value': 'Kg'},
#     {'cell_value': ''},
#     {'cell_value': ''},
#     {'cell_value': ''}],
#    'type': 'table_header'},
#   {'block_idx': 297,
#    'cells': [{'cell_value': 'Compacta VariO 8'},
#     {'cell_value': '60'},
#     {'cell_value': '77'},
#     {'cell_value': '153'},
#     {'cell_value': '290'},
#     {'cell_value': ''},
#     {'cell_value': ''},
#     {'cell_value': ''}],
#    'type': 'table_data_row'},
#   {'block_idx': 298,
# ...

# %%
doc.chunks[190]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/alexander/saia/proyectos/iceteam/notebooks/pdf-ingestion-2.ipynb Cell 17 line 1
# ----> <a href='vscode-notebook-cell:/Users/alexander/saia/proyectos/iceteam/notebooks/pdf-ingestion-2.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> doc.chunks[190]
#
# TypeError: 'method' object is not subscriptable

# %%
for chunk in doc.chunks():
    print(chunk.paragraphs())
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...
